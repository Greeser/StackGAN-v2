# %%
import bcolz
import numpy as np
import pickle
import pandas as pd
import re

# %%
GLOVE_PATH= "./glovo_6B"
FILEPATH = "./shoes_v2.csv"

# %%
words = []
idx = 0
word2idx = {}
vectors = bcolz.carray(np.zeros(1), rootdir=f'glove_6B/glovo.6B.50d.dat', mode='w')

with open(f'glove_6B/glove.6B.50d.txt', 'rb') as f:
    for l in f:
        line = l.decode().split()
        word = line[0]
        words.append(word)
        word2idx[word] = idx
        idx += 1
        vect = np.array(line[1:]).astype(np.float)
        vectors.append(vect)
    
vectors = bcolz.carray(vectors[1:].reshape((400000, 50)), rootdir=f'/home/gr/UT/LIP/project/glove_6B/glovo.6B.50d.dat', mode='w')
vectors.flush()
pickle.dump(words, open(f'/home/gr/UT/LIP/project/glove_6B/glovo.6B.50d_words.pkl', 'wb'))
pickle.dump(word2idx, open(f'/home/gr/UT/LIP/project/glove_6B/glovo.6B.50d_idx.pkl', 'wb'))

# %%
vectors = bcolz.open(f'glove_6B/glovo.6B.50d.dat')[:]
words = pickle.load(open(f'glove_6B/glovo.6B.50d_words.pkl', 'rb'))
word2idx = pickle.load(open(f'glove_6B/glovo.6B.50d_idx.pkl', 'rb'))

glove = {w: vectors[word2idx[w]] for w in words}

# %%
shoes = pd.read_csv('shoes_v2.csv')

# %%
shoes.head()
# Out:
#    Unnamed: 0         CID Category SubCategory     HeelHeight  \
# 0           0   100627-72    Shoes     Oxfords            NaN
# 1           1  100627-255    Shoes     Oxfords            NaN
# 2           2   100657-72    Shoes     Oxfords            NaN
# 3           3  100657-216    Shoes     Oxfords            NaN
# 4           4    101026-3    Boots    Mid-Calf  1in - 1 3/4in
#
#                      Insole      Closure   Gender               Material  \
# 0                   Leather  ['Lace up']  ['Men']            ['Leather']
# 1                   Leather  ['Lace up']  ['Men']            ['Leather']
# 2  Leather;Padded;Removable  ['Lace up']  ['Men']            ['Leather']
# 3  Leather;Padded;Removable  ['Lace up']  ['Men']            ['Leather']
# 4            Leather;Padded  ['Pull-on']  ['Men']  ['Leather', 'Rubber']
#
#                 ToeStyle      Brand                           Url  \
# 0   Capped Toe;Round Toe  Bostonian   Shoes/Oxfords/100627.72.jpg
# 1   Capped Toe;Round Toe  Bostonian  Shoes/Oxfords/100627.255.jpg
# 2   Capped Toe;Round Toe  Bostonian   Shoes/Oxfords/100657.72.jpg
# 3   Capped Toe;Round Toe  Bostonian  Shoes/Oxfords/100657.216.jpg
# 4  Square Toe;Closed Toe    Durango   Boots/Mid-Calf/101026.3.jpg
#
#   unique_Closure unique_Gender unique_Material
# 0        Lace up           Men         Leather
# 1        Lace up           Men         Leather
# 2        Lace up           Men         Leather
# 3        Lace up           Men         Leather
# 4        Pull-on           Men         Leather

# %%
shoes = shoes.fillna("")

# %%
text = ""
for col in ['SubCategory', 'Brand', 'unique_Closure', 'unique_Gender', 'unique_Material']:
    tmp = " ".join(shoes[col].unique().tolist())
    text += tmp
text = text.split()
text = [t.lower() for t in text]

# %%
text
# Out:
# ['oxfords',
#  'mid-calf',
#  'heel',
#  'ankle',
#  'boot',
#  'loafers',
#  'slipper',
#  'flats',
#  'boat',
#  'shoes',
#  'flat',
#  'clogs',
#  'and',
#  'mules',
#  'flats',
#  'sneakers',
#  'and',
#  'athletic',
#  'shoes',
#  'slipper',
#  'heels',
#  'heels',
#  'athletic',
#  'prewalker',
#  'knee',
#  'high',
#  'prewalker',
#  'boots',
#  'crib',
#  'shoes',
#  'firstwalker',
#  'over',
#  'the',
#  'kneebostonian',
#  'durango',
#  'finn',
#  'comfort',
#  'frye',
#  'hush',
#  'puppies',
#  'minnetonka',
#  'nunn',
#  'bush',
#  'skechers',
#  'sperry',
#  'top-sider',
#  'stacy',
#  'adams',
#  'bass',
#  'wolky',
#  'hush',
#  'puppies',
#  'kids',
#  'klogs',
#  'usa',
#  'vans',
#  'ecco',
#  'florsheim',
#  'sebago',
#  'propet',
#  'dr.',
#  'martens',
#  'birkenstock',
#  "birki's",
#  'l.b.',
#  'evans',
#  'softwalk',
#  'daniel',
#  'green',
#  'easy',
#  'spirit',
#  'clarks',
#  'reebok',
#  'lifestyle',
#  'rockport',
#  'new',
#  'balance',
#  'deer',
#  'stags',
#  'ugg',
#  'franco',
#  'sarto',
#  'caterpillar',
#  'lugz',
#  'wolverine',
#  'converse',
#  'old',
#  'friend',
#  'k-swiss',
#  'dockers',
#  'keds',
#  'sesto',
#  'meucci',
#  'timberland',
#  'kenneth',
#  'cole',
#  'reaction',
#  'naot',
#  'footwear',
#  'trotters',
#  'ugg',
#  'kids',
#  'carlos',
#  'by',
#  'carlos',
#  'santana',
#  'pro-keds',
#  'mephisto',
#  'saucony',
#  'papillio',
#  'timberland',
#  'pro',
#  'adidas',
#  'rieker',
#  'new',
#  'balance',
#  'classics',
#  'palladium',
#  'allen-edmonds',
#  'kangaroos',
#  'sorel',
#  'dunham',
#  'columbia',
#  'dansko',
#  'annie',
#  'john',
#  'fluevog',
#  'adidas',
#  'kids',
#  'timberland',
#  'kids',
#  'vans',
#  'kids',
#  'stride',
#  'rite',
#  'kamik',
#  'kids',
#  'onitsuka',
#  'tiger',
#  'by',
#  'asics',
#  'donald',
#  'j',
#  'pliner',
#  "birki's",
#  'kids',
#  'birkenstock',
#  'kids',
#  'salt',
#  'water',
#  'sandal',
#  'by',
#  'hoy',
#  'shoes',
#  'keen',
#  'kenneth',
#  'cole',
#  'reaction',
#  'kids',
#  'allrounder',
#  'by',
#  'mephisto',
#  'reebok',
#  'kids',
#  'converse',
#  'kids',
#  'skechers',
#  'work',
#  'taryn',
#  'rose',
#  'asolo',
#  'nurse',
#  'mates',
#  'vasque',
#  'capezio',
#  'bloch',
#  'chinese',
#  'laundry',
#  'ariat',
#  'la',
#  'sportiva',
#  'capezio',
#  'kids',
#  'steve',
#  'madden',
#  'rocket',
#  'dog',
#  'lucchese',
#  'ralph',
#  'lauren',
#  'layette',
#  'kids',
#  'gola',
#  'stuart',
#  'weitzman',
#  'ipath',
#  'softspots',
#  'johnston',
#  '&',
#  'murphy',
#  'shoe',
#  'be',
#  'doo',
#  'durango',
#  'kids',
#  'kenneth',
#  'cole',
#  'new',
#  'york',
#  'j.',
#  'renee',
#  'ros',
#  'hommerson',
#  'kamik',
#  'dexter',
#  'bowling',
#  'acorn',
#  'baffin',
#  'nina',
#  'kids',
#  'frye',
#  'kids',
#  'puma',
#  'crocs',
#  'pelle',
#  'moda',
#  'giorgio',
#  'brutini',
#  'foamtreads',
#  'kids',
#  'lowa',
#  "designer's",
#  'touch',
#  'kids',
#  'spira',
#  'five',
#  'ten',
#  'pf',
#  'flyers',
#  'sam',
#  'edelman',
#  'saucony',
#  'originals',
#  'montrail',
#  'sanuk',
#  'emerica',
#  'chippewa',
#  'globe',
#  'cordani',
#  'la',
#  'canadienne',
#  'adidas',
#  'originals',
#  'jumping',
#  'jacks',
#  'kids',
#  'ocean',
#  'minded',
#  'dc',
#  'dvs',
#  'shoe',
#  'company',
#  'sperry',
#  'kids',
#  'justin',
#  'dc',
#  'kids',
#  'arche',
#  'circa',
#  'lacrosse',
#  'western',
#  'chief',
#  'kids',
#  'walking',
#  'cradles',
#  'ecco',
#  'sport',
#  'tretorn',
#  'fila',
#  'nine',
#  'west',
#  'el',
#  'naturalista',
#  'soft',
#  'style',
#  'onex',
#  'enzo',
#  'angiolini',
#  'tundra',
#  'kids',
#  'boots',
#  'reef',
#  'chaco',
#  'vaneli',
#  'rollerblade',
#  'naturalizer',
#  'camper',
#  'josef',
#  'seibel',
#  'keds',
#  'kids',
#  'pleaser',
#  'usa',
#  'lakai',
#  'kid',
#  'express',
#  'hi-tec',
#  'magnum',
#  'bruno',
#  'magli',
#  'fratelli',
#  'the',
#  'north',
#  'face',
#  'kids',
#  'prince',
#  'ektelon',
#  'roper',
#  'rsvp',
#  'acorn',
#  'kids',
#  'school',
#  'issue',
#  'pajar',
#  'david',
#  'tate',
#  'crocs',
#  'kids',
#  'circa',
#  'kids',
#  'old',
#  'gringo',
#  'yellow',
#  'box',
#  'ara',
#  'beautifeel',
#  'volatile',
#  'dingo',
#  'osiris',
#  'tsukihoshi',
#  'kids',
#  'dansko',
#  'kids',
#  'kork-ease',
#  'olukai',
#  'kate',
#  'spade',
#  'new',
#  'york',
#  'irish',
#  'setter',
#  'diadora',
#  'french',
#  'sole',
#  'bogs',
#  'zamberlan',
#  'sporto',
#  'diesel',
#  'creative',
#  'recreation',
#  'harley-davidson',
#  'keen',
#  'kids',
#  'eastland',
#  'foamtreads',
#  'teva',
#  'kids',
#  'robeez',
#  'helle',
#  'comfort',
#  'globe',
#  'kids',
#  'calvin',
#  'klein',
#  'fitzwell',
#  'drew',
#  'think!',
#  'jessica',
#  'simpson',
#  'pediped',
#  'gentle',
#  'souls',
#  'inov-8',
#  'see',
#  'kai',
#  'run',
#  'kids',
#  'fly',
#  'flot',
#  'tic',
#  'tac',
#  'toes',
#  'anne',
#  'klein',
#  'camper',
#  'kids',
#  'lilly',
#  'pulitzer',
#  'cole',
#  'haan',
#  'arcopedico',
#  'chicago',
#  'skates',
#  'tsubo',
#  'eric',
#  'michael',
#  'oakley',
#  'sorel',
#  'kids',
#  'daniblack',
#  'michael',
#  'michael',
#  'kors',
#  'bandolino',
#  'hunter',
#  'avia',
#  'ryka',
#  'scarpa',
#  't.u.k%2e',
#  'smartdogs',
#  'lauren',
#  'ralph',
#  'lauren',
#  'coloriffics',
#  'etnies',
#  'type',
#  'z',
#  'born',
#  'dr.',
#  "scholl's",
#  'supra',
#  'ragg',
#  'kids',
#  'emu',
#  'australia',
#  'kids',
#  'touch',
#  'ups',
#  'diba',
#  'nike',
#  'kids',
#  'mia',
#  'red',
#  'wing',
#  'heritage',
#  'gabriella',
#  'rocha',
#  'reebok',
#  'team',
#  'etnies',
#  'kids',
#  'teva',
#  'circa',
#  'joan',
#  '&',
#  'david',
#  'la',
#  'plume',
#  'laredo',
#  'de',
#  'osu',
#  'kids',
#  'lacoste',
#  'guess',
#  "kids'",
#  'steven',
#  'juicy',
#  'couture',
#  'original',
#  'penguin',
#  'bella-vita',
#  'dirk',
#  'bikkembergs',
#  'nike',
#  'worx',
#  'by',
#  'red',
#  'wing',
#  'shoes',
#  'nina',
#  'macbeth',
#  'tony',
#  'lama',
#  'corso',
#  'como',
#  'cobian',
#  'reef',
#  'kids',
#  'footmates',
#  'brooks',
#  'aetrex',
#  'hatley',
#  'kids',
#  'salomon',
#  'clae',
#  'superga',
#  'kids',
#  'superga',
#  'lifestride',
#  'adidas',
#  'originals',
#  'kids',
#  'converse',
#  'work',
#  'to',
#  'boot',
#  'new',
#  'york',
#  'mia',
#  'kids',
#  'pf',
#  'flyers',
#  'kids',
#  'garmont',
#  'charles',
#  'by',
#  'charles',
#  'david',
#  'stuart',
#  'weitzman',
#  'bridal',
#  '&',
#  'evening',
#  'collection',
#  'pablosky',
#  'kids',
#  'naturino',
#  'pazitos',
#  'merrell',
#  'kids',
#  'john',
#  'varvatos',
#  'merrell',
#  'vivanz',
#  'patagonia',
#  'blundstone',
#  'bates',
#  'footwear',
#  'tecnica',
#  "o'neill",
#  'polo',
#  'ralph',
#  'lauren',
#  'kors',
#  'michael',
#  'kors',
#  'callaway',
#  'jessica',
#  'simpson',
#  'kids',
#  'hi-tec',
#  'kids',
#  'patricia',
#  'green',
#  'quiksilver',
#  'kids',
#  'tretorn',
#  'kids',
#  'skechers',
#  'kids',
#  'nautilus',
#  'romika',
#  'aravon',
#  'spring',
#  'step',
#  "o'neill",
#  'kids',
#  'bernardo',
#  'a.',
#  'testoni',
#  'nine',
#  'west',
#  'kids',
#  'dan',
#  'post',
#  'madden',
#  'girl',
#  'fred',
#  'perry',
#  'havaianas',
#  'nike',
#  'action',
#  'kids',
#  'onitsuka',
#  'tiger',
#  'kids',
#  'by',
#  'asics',
#  'asics',
#  'sidi',
#  'puma',
#  'kids',
#  'the',
#  'north',
#  'face',
#  'emu',
#  'australia',
#  'pikolinos',
#  'gravis',
#  'j-41',
#  'diane',
#  'von',
#  'furstenberg',
#  'golite',
#  'paris',
#  'hilton',
#  'neil',
#  'm%2e',
#  'khombu',
#  'aquatalia',
#  'by',
#  'marvin',
#  'k%2e',
#  'bc',
#  'footwear',
#  'rj',
#  'colt',
#  'munro',
#  'american',
#  'nike',
#  'action',
#  'k-swiss',
#  'kids',
#  'sanita',
#  'asics',
#  'kids',
#  'romantic',
#  'soles',
#  'adidas',
#  'y-3',
#  'by',
#  'yohji',
#  'yamamoto',
#  'ralph',
#  'lauren',
#  'collection',
#  'element',
#  'boss',
#  'black',
#  'adidas',
#  'running',
#  'ahnu',
#  'ecco',
#  'golf',
#  'me',
#  'too',
#  'mbt',
#  'adidas',
#  'golf',
#  'volcom',
#  'kalso',
#  'earth',
#  'fallen',
#  'brighton',
#  'converse',
#  'by',
#  'john',
#  'varvatos',
#  'dirty',
#  'laundry',
#  'ziera',
#  'true',
#  'religion',
#  'sofft',
#  'fitflop',
#  'badgley',
#  'mischka',
#  'hunter',
#  'kids',
#  'adidas',
#  'by',
#  'stella',
#  'mccartney',
#  'sanuk',
#  'kids',
#  'jambu',
#  'columbia',
#  'kids',
#  'unlisted',
#  'sergio',
#  'rossi',
#  'tommy',
#  'bahama',
#  'roxy',
#  'kids',
#  'ecco',
#  'kids',
#  'burberry',
#  'umi',
#  'kids',
#  'athena',
#  'alexander',
#  'callisto',
#  'of',
#  'california',
#  'geox',
#  'pour',
#  'la',
#  'victoire',
#  'axion',
#  'roper',
#  'kids',
#  'woolrich',
#  'primigi',
#  'kids',
#  'dkny',
#  'cole',
#  'haan',
#  'kids',
#  'gypsy',
#  'soule',
#  'stetson',
#  'heelys',
#  'garvalin',
#  'kids',
#  'vigotti',
#  'giesswein',
#  'mezlan',
#  'salvatore',
#  'ferragamo',
#  'bcbgeneration',
#  'loeffler',
#  'randall',
#  'bogs',
#  'kids',
#  'a',
#  'line',
#  'amiana',
#  'flojos',
#  'morgan&milo',
#  'kids',
#  'volatile',
#  'kids',
#  'guess',
#  'fergie',
#  'ariat',
#  'kids',
#  'fratelli',
#  'rossetti',
#  'habitat',
#  'evolv',
#  'clarks',
#  'kids',
#  'dyeables',
#  'mizuno',
#  'livie',
#  '&',
#  'luca',
#  'creative',
#  'recreation',
#  'kids',
#  'bloch',
#  'kids',
#  'native',
#  'shoes',
#  'pearl',
#  'izumi',
#  'wilson',
#  'robert',
#  'wayne',
#  'cushe',
#  'keen',
#  'utility',
#  'lassen',
#  'jil',
#  'sander',
#  'donna',
#  'karan',
#  'blowfish',
#  'zoot',
#  'sports',
#  'shimano',
#  'new',
#  'balance',
#  'kids',
#  'caparros',
#  'seychelles',
#  'roxy',
#  'chrome',
#  'saucony',
#  'kids',
#  'stuart',
#  'weitzman',
#  'kids',
#  'agatha',
#  'ruiz',
#  'de',
#  'la',
#  'prada',
#  'kids',
#  'olukai',
#  'kids',
#  'gravati',
#  'native',
#  'kids',
#  'shoes',
#  'gwyneth',
#  'polo',
#  'ralph',
#  'lauren',
#  'kids',
#  'geox',
#  'kids',
#  'nike',
#  'golf',
#  'vintage',
#  'shoe',
#  'company',
#  'k2',
#  'skates',
#  'michael',
#  'antonio',
#  'elephantito',
#  'gabor',
#  'salomon',
#  'kids',
#  'mozo',
#  'oh!',
#  'shoes',
#  'call',
#  'it',
#  'spring',
#  'proenza',
#  'schouler',
#  'rachel',
#  'kids',
#  'caterpillar',
#  'casual',
#  'puma',
#  'sport',
#  'fashion',
#  'spenco',
#  'minnetonka',
#  'kids',
#  'biviel',
#  'seavees',
#  'orthaheel',
#  'lucky',
#  'brand',
#  'patagonia',
#  'kids',
#  'naughty',
#  'monkey',
#  'emerald',
#  'by',
#  'element',
#  'havaianas',
#  'kids',
#  'ivanka',
#  'trump',
#  'chaco',
#  'kids',
#  'haflinger',
#  'elizabeth',
#  'and',
#  'james',
#  'bedstu',
#  'jack',
#  'rogers',
#  'lumiani',
#  'jambu',
#  'kids',
#  'diadora',
#  'kids',
#  'alegria',
#  'khombu',
#  'kids',
#  'osiris',
#  'kids',
#  'christin',
#  'michaels',
#  'privo',
#  'by',
#  'clarks',
#  'vidorreta',
#  'earthies',
#  'freewaters',
#  'tecnica',
#  'kids',
#  'superfeet',
#  'lounge',
#  'by',
#  'mark',
#  'nason',
#  'scott',
#  'hawaii',
#  'pedro',
#  'garcia',
#  'black',
#  'rooster',
#  'superfit',
#  'beeko',
#  "levi's",
#  'shoes',
#  'calvin',
#  'klein',
#  'collection',
#  "levi's",
#  'kids',
#  'vivobarefoot',
#  'favorite',
#  'characters',
#  'little',
#  'marc',
#  'jacobs',
#  'amalfi',
#  'by',
#  'rangoni',
#  'old',
#  'west',
#  'kids',
#  'boots',
#  'dknyc',
#  'aster',
#  'kids',
#  'giuseppe',
#  'zanotti',
#  'bikkembergs',
#  'ted',
#  'baker',
#  'nicole',
#  'twig',
#  'kids',
#  'pampili',
#  'cienta',
#  'kids',
#  'shoes',
#  'venettini',
#  'kids',
#  'big',
#  'buddha',
#  'marc',
#  'jacobs',
#  'moschino',
#  'calvin',
#  'klein',
#  'jeans',
#  'tundra',
#  'boots',
#  'speedo',
#  'vince',
#  'camuto',
#  'bouquets',
#  'w.a.g%2e',
#  'brooks',
#  'kids',
#  'vineyard',
#  'vines',
#  'reebok',
#  'le',
#  'chameau',
#  'enzo',
#  'kids',
#  'joan',
#  '&',
#  'david',
#  'generic',
#  'surplus',
#  'dv',
#  'by',
#  'dolce',
#  'vita',
#  'dolce',
#  'vita',
#  'two',
#  'lips',
#  'ugg',
#  'collection',
#  'spirit',
#  'by',
#  'lucchese',
#  'vera',
#  'bradley',
#  'kickers',
#  'adidas',
#  'outdoor',
#  'robert',
#  'clergerie',
#  'juicy',
#  'couture',
#  'kids',
#  'sendra',
#  'alexander',
#  'mcqueen',
#  'paul',
#  'smith',
#  'vivienne',
#  'westwood',
#  'vera',
#  'wang',
#  'lavender',
#  'label',
#  'indigo',
#  'by',
#  'clarks',
#  'justin',
#  'kids',
#  'earth',
#  'michael',
#  'kors',
#  ...]

# %%
for t in text:
    if t.startswith("bos"):
        print(t)
# Out:
# boss
# boss
# boss

# %%
cut_df = shoes[['SubCategory', 'Brand', 'unique_Closure', 'unique_Gender', 'unique_Material']]

# %%
sent_list = cut_df.values.tolist()
sent_list = [' '.join(t) for t in sent_list]
sent_list = [re.sub(r'[^\w]', ' ', t) for t in sent_list]

# %%
sent_list = [t.split() for t in sent_list]
sent_list = [[s.lower() for s in t] for t in sent_list]
sent_list
# Out:
# [['oxfords', 'bostonian', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'bostonian', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'bostonian', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'bostonian', 'lace', 'up', 'men', 'leather'],
#  ['mid', 'calf', 'durango', 'pull', 'on', 'men', 'leather'],
#  ['mid', 'calf', 'durango', 'pull', 'on', 'men', 'rubber'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'nappa'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'buckle', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'ankle', 'strap', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['heel', 'finn', 'comfort', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'men', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'men', 'neoprene'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'men', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'men', 'neoprene'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'leather'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'neoprene'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'rubber'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'suede'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'leather'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'neoprene'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'rubber'],
#  ['ankle', 'frye', 'pull', 'on', 'men', 'suede'],
#  ['ankle', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['ankle', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'neoprene'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'suede'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'neoprene'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'suede'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'neoprene'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'suede'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'neoprene'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'frye', 'zipper', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['mid', 'calf', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['ankle', 'frye', 'pull', 'on', 'women', 'leather'],
#  ['ankle', 'frye', 'pull', 'on', 'women', 'neoprene'],
#  ['ankle', 'frye', 'pull', 'on', 'women', 'rubber'],
#  ['ankle', 'frye', 'pull', 'on', 'women', 'suede'],
#  ['oxfords', 'hush', 'puppies', 'hook', 'and', 'loop', 'men', 'leather'],
#  ['oxfords', 'hush', 'puppies', 'hook', 'and', 'loop', 'men', 'leather'],
#  ['oxfords', 'hush', 'puppies', 'hook', 'and', 'loop', 'men', 'leather'],
#  ['boot', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'men', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['slipper', 'flats', 'minnetonka', 'zipper', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'suede'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'suede'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'suede'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'suede'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'suede'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'slip', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'lace', 'up', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'minnetonka', 'pull', 'on', 'women', 'suede'],
#  ['ankle', 'nunn', 'bush', 'zipper', 'men', 'leather'],
#  ['oxfords', 'skechers', 'lace', 'up', 'men'],
#  ['oxfords', 'skechers', 'lace', 'up', 'men'],
#  ['boat', 'shoes', 'sperry', 'top', 'sider', 'slip', 'on', 'women', 'canvas'],
#  ['boat', 'shoes', 'sperry', 'top', 'sider', 'slip', 'on', 'women', 'canvas'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'men', 'leather'],
#  ['ankle', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['flat', 'bass', 'slip', 'on', 'women', 'leather'],
#  ['flat', 'bass', 'slip', 'on', 'women', 'suede'],
#  ['flat', 'bass', 'slip', 'on', 'women', 'leather'],
#  ['flat', 'bass', 'slip', 'on', 'women', 'suede'],
#  ['flat', 'bass', 'slip', 'on', 'women', 'leather'],
#  ['flat', 'bass', 'slip', 'on', 'women', 'suede'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'buckle', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['flat', 'wolky', 'hook', 'and', 'loop', 'women', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'stacy', 'adams', 'lace', 'up', 'men', 'ostrich'],
#  ['oxfords', 'hush', 'puppies', 'kids', 'lace', 'up', 'boys'],
#  ['oxfords', 'hush', 'puppies', 'kids', 'lace', 'up', 'boys'],
#  ['clogs',
#   'and',
#   'mules',
#   'klogs',
#   'usa',
#   'slip',
#   'on',
#   'women',
#   'polyurethane'],
#  ['clogs',
#   'and',
#   'mules',
#   'klogs',
#   'usa',
#   'slip',
#   'on',
#   'women',
#   'polyurethane'],
#  ['clogs',
#   'and',
#   'mules',
#   'klogs',
#   'usa',
#   'slip',
#   'on',
#   'women',
#   'polyurethane'],
#  ['flats', 'hush', 'puppies', 'women'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
# ...
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'cotton'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'cotton'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'cotton'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'cotton'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'cotton'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'men',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'cotton'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'suede'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'canvas'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'cotton'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'rubber'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'vans',
#   'lace',
#   'up',
#   'women',
#   'suede'],
#  ['oxfords', 'ecco', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'ecco', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'ecco', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'ecco', 'lace', 'up', 'men', 'nubuck'],
#  ['ankle', 'ecco', 'lace', 'up', 'men', 'leather'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['loafers', 'florsheim', 'men'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['loafers', 'florsheim', 'men'],
#  ['loafers', 'florsheim', 'men'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'sheepskin'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'sheepskin'],
#  ['ankle', 'florsheim', 'zipper', 'men', 'leather'],
#  ['ankle', 'florsheim', 'zipper', 'men', 'rubber'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['oxfords', 'florsheim', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'florsheim', 'lace', 'up', 'men', 'hair', 'calf'],
#  ['oxfords', 'florsheim', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'florsheim', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'florsheim', 'lace', 'up', 'men', 'leather'],
#  ['loafers', 'florsheim', 'slip', 'on', 'men', 'leather'],
#  ['loafers', 'florsheim', 'elastic', 'gore', 'men', 'leather'],
#  ['loafers', 'florsheim', 'elastic', 'gore', 'men', 'leather'],
#  ['loafers', 'florsheim', 'elastic', 'gore', 'men', 'leather'],
#  ['loafers', 'sebago', 'slip', 'on', 'men', 'full', 'grain', 'leather'],
#  ['loafers', 'sebago', 'slip', 'on', 'men', 'full', 'grain', 'leather'],
#  ['loafers', 'sebago', 'slip', 'on', 'men', 'full', 'grain', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men', 'nubuck'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men', 'nubuck'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'men'],
#  ['boat', 'shoes', 'sebago', 'men', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'women', 'leather'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'women', 'nubuck'],
#  ['boat', 'shoes', 'sebago', 'lace', 'up', 'women', 'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'men',
#   'nubuck'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'men',
#   'nubuck'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'men',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'men',
#   'nubuck'],
#  ['ankle', 'propet', 'lace', 'up', 'men', 'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'hook',
#   'and',
#   'loop',
#   'men',
#   'full',
#   'grain',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'hook',
#   'and',
#   'loop',
#   'men',
#   'leather'],
#  ['oxfords', 'propet', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'propet', 'lace', 'up', 'men', 'leather'],
#  ['flat', 'propet', 'hook', 'and', 'loop', 'men', 'leather'],
#  ['flat', 'propet', 'hook', 'and', 'loop', 'men', 'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'women',
#   'nubuck'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'women',
#   'nubuck'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['sneakers',
#   'and',
#   'athletic',
#   'shoes',
#   'propet',
#   'lace',
#   'up',
#   'women',
#   'leather'],
#  ['oxfords', 'propet', 'lace', 'up', 'women', 'leather'],
#  ['oxfords', 'propet', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'full', 'grain', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'full', 'grain', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['oxfords',
#   'dr',
#   'martens',
#   'lace',
#   'up',
#   'women',
#   'full',
#   'grain',
#   'leather'],
#  ['oxfords', 'dr', 'martens', 'lace', 'up', 'women', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'full', 'grain', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'leather'],
#  ['ankle', 'dr', 'martens', 'lace', 'up', 'men', 'suede'],
#  ['flat', 'birkenstock', 'buckle', 'women', 'suede'],
#  ['clogs', 'and', 'mules', 'birki', 's', 'slip', 'on', 'men', 'polyurethane'],
#  ['clogs', 'and', 'mules', 'birki', 's', 'slip', 'on', 'men', 'synthetic'],
#  ['clogs', 'and', 'mules', 'birki', 's', 'slip', 'on', 'men', 'polyurethane'],
#  ['clogs', 'and', 'mules', 'birki', 's', 'slip', 'on', 'men', 'synthetic'],
#  ['clogs',
#   'and',
#   'mules',
#   'birki',
#   's',
#   'slip',
#   'on',
#   'women',
#   'polyurethane'],
#  ['clogs', 'and', 'mules', 'birki', 's', 'slip', 'on', 'women', 'synthetic'],
#  ['clogs',
#   'and',
#   'mules',
#   'birki',
#   's',
#   'slip',
#   'on',
#   'women',
#   'polyurethane'],
#  ['clogs', 'and', 'mules', 'birki', 's', 'slip', 'on', 'women', 'synthetic'],
#  ['slipper', 'flats', 'l', 'b', 'evans', 'men', 'leather'],
#  ['slipper', 'flats', 'l', 'b', 'evans', 'men', 'leather'],
#  ['slipper', 'flats', 'l', 'b', 'evans', 'men', 'leather'],
#  ['slipper', 'flats', 'l', 'b', 'evans', 'men', 'leather'],
#  ['slipper', 'flats', 'l', 'b', 'evans', 'men', 'leather'],
#  ['flats', 'softwalk', 'slip', 'on', 'women', 'leather'],
#  ['flats', 'softwalk', 'slip', 'on', 'women', 'leather'],
#  ['flats', 'softwalk', 'slip', 'on', 'women', 'leather'],
#  ['flats', 'softwalk', 'slip', 'on', 'women', 'leather'],
#  ['loafers', 'minnetonka', 'men', 'leather'],
#  ['slipper', 'flats', 'l', 'b', 'evans', 'slip', 'on', 'men', 'deerskin'],
#  ['mid', 'calf', 'durango', 'pull', 'on', 'men', 'leather'],
#  ['mid', 'calf', 'durango', 'pull', 'on', 'men', 'rubber'],
#  ['slipper',
#   'heels',
#   'daniel',
#   'green',
#   'slip',
#   'on',
#   'women',
#   'faux',
#   'leather'],
#  ['slipper',
#   'heels',
#   'daniel',
#   'green',
#   'slip',
#   'on',
#   'women',
#   'faux',
#   'leather'],
#  ...]

# %%
sent_one_list = cut_df.values.flatten().tolist()
sent_one_list = ' '.join(sent_one_list)
sent_one_list = re.sub(r'[^\w]', ' ', sent_one_list)

# %%
sent_one_list = sent_one_list.split(' ')
sent_one_list = [t.lower() for t in sent_one_list]
sent_one_list_unique = list(set(sent_one_list))
sent_list_add = ['pad', 'bos', 'eos', 'unk']
sent_one_list_unique = sent_list_add + sent_one_list_unique
len(sent_one_list_unique)
# Out:
# 893

# %%
sent_one_list_unique
# Out:
# ['pad',
#  'bos',
#  'eos',
#  'unk',
#  '',
#  'supra',
#  'drop',
#  'mates',
#  'pull',
#  'habitat',
#  'zipper',
#  'kai',
#  'camuto',
#  'prewalker',
#  'prana',
#  'white',
#  'rebecca',
#  'murphy',
#  'spade',
#  'ragg',
#  'garmont',
#  'sport',
#  'soft',
#  'favorite',
#  'vinyl',
#  'grain',
#  'dc',
#  'loves',
#  'gabor',
#  'kickers',
#  'of',
#  'roper',
#  'umi',
#  'just',
#  'miz',
#  'horse',
#  'strap',
#  'gringo',
#  'pliner',
#  'lacrosse',
#  'lucky',
#  'velvet',
#  'over',
#  'reef',
#  'g',
#  'joie',
#  'coloriffics',
#  'ferragamo',
#  'giuseppe',
#  'generic',
#  'cashmere',
#  'heelys',
#  'exotic',
#  'mountrek',
#  'back',
#  'vibram',
#  'malibu',
#  'rooster',
#  'hawaii',
#  'terry',
#  'garcia',
#  's',
#  'wayne',
#  'tiger',
#  'onitsuka',
#  'florsheim',
#  'el',
#  'wrap',
#  'fitflop',
#  'flex',
#  'juicy',
#  'bates',
#  'comfort',
#  'dingo',
#  'gentle',
#  'riding',
#  'modern',
#  'reebok',
#  'distressed',
#  'nike',
#  'gabriella',
#  'softspots',
#  'spirit',
#  'canvas',
#  'laundry',
#  'edelman',
#  'rocha',
#  'gypsy',
#  'salvatore',
#  'shearling',
#  'miss',
#  'mcqueen',
#  'jamie',
#  'little',
#  'timberland',
#  'pikolinos',
#  'justin',
#  'dare',
#  'havaianas',
#  'morgan',
#  'green',
#  'dansko',
#  'pulitzer',
#  'hush',
#  'ostrich',
#  '2e',
#  'calf',
#  'yamamoto',
#  'national',
#  'school',
#  'mozo',
#  'jack',
#  'lizard',
#  'minded',
#  'acrylic',
#  'ankle',
#  'native',
#  'bottega',
#  'shimano',
#  'sperry',
#  'mathew',
#  'giorgio',
#  'running',
#  'jil',
#  'veneta',
#  '7',
#  'bebe',
#  'or',
#  'propet',
#  'swiss',
#  'diadora',
#  'mark',
#  'earthies',
#  'buckle',
#  'globe',
#  'leather',
#  'spring',
#  'crochet',
#  'pf',
#  'sorel',
#  'cienta',
#  'tecnica',
#  'capezio',
#  'toes',
#  'woolrich',
#  'fivefingers',
#  'new',
#  'company',
#  'mephisto',
#  'microfiber',
#  'team',
#  'fendi',
#  'the',
#  'jacquard',
#  'dunham',
#  'hook',
#  'y',
#  'footmates',
#  'york',
#  'collection',
#  'hilton',
#  'jute',
#  'stella',
#  'guess',
#  'two',
#  'john',
#  'diba',
#  'lambskin',
#  'robeez',
#  'dockers',
#  'dirk',
#  'corso',
#  'scholl',
#  'paris',
#  'ziera',
#  'angiolini',
#  'k2',
#  'oh',
#  'sling',
#  'lace',
#  'ahnu',
#  'rubber',
#  'davidson',
#  'western',
#  'pedro',
#  'outdoor',
#  'balance',
#  'vita',
#  'lumiani',
#  'yohji',
#  'jd',
#  'olukai',
#  '8',
#  'varvatos',
#  'lifestyle',
#  'nubuck',
#  'eva',
#  'lacoste',
#  'puppies',
#  'ryka',
#  'evans',
#  'neil',
#  'adams',
#  'converse',
#  'dexter',
#  'mischka',
#  'pleaser',
#  'matisse',
#  'designer',
#  'creative',
#  'no',
#  'boot',
#  'finn',
#  'naot',
#  'wing',
#  'fitzwell',
#  'linen',
#  'sportiva',
#  'kork',
#  'pablosky',
#  'big',
#  'hugo',
#  'tsubo',
#  'fluevog',
#  'hommerson',
#  'bostonian',
#  'giro',
#  'crocodile',
#  'taos',
#  'sendra',
#  'ivanka',
#  'osu',
#  'irregular',
#  'softwalk',
#  'chicago',
#  'simpson',
#  'fidji',
#  'poetic',
#  'boys',
#  'dkny',
#  'edition',
#  'sidi',
#  'dirty',
#  'usa',
#  'grazie',
#  'rocket',
#  'west',
#  'circa',
#  'michael',
#  'brighton',
#  'sneakers',
#  'body',
#  'seibel',
#  'work',
#  'christin',
#  'm',
#  'palladium',
#  'touch',
#  'bogs',
#  'all',
#  'loafers',
#  'chiffon',
#  'arche',
#  'klogs',
#  'wolverine',
#  'aluminum',
#  'wool',
#  'fisk',
#  'love',
#  'neill',
#  'martens',
#  'jessica',
#  'suede',
#  'naughty',
#  't',
#  'mid',
#  'heel',
#  'heels',
#  'vivienne',
#  'prada',
#  'sadock',
#  'david',
#  'on',
#  'lauren',
#  'polyester',
#  'yellow',
#  'kids',
#  'como',
#  'one',
#  'indigo',
#  'fratelli',
#  'haan',
#  'soule',
#  'lucchese',
#  'fleece',
#  'nina',
#  'lavender',
#  'athena',
#  'bella',
#  'mccartney',
#  'moda',
#  'chief',
#  'lilly',
#  'elastic',
#  'von',
#  'luca',
#  'moschino',
#  'armani',
#  'not',
#  'kenny',
#  'diane',
#  'daniblack',
#  'munro',
#  'baffin',
#  'a',
#  'easy',
#  'johnston',
#  'kenneth',
#  'bahama',
#  'ralph',
#  'proenza',
#  'rated',
#  'action',
#  'joe',
#  'pour',
#  'athletic',
#  'ariat',
#  'dsquared2',
#  'zamberlan',
#  'cesare',
#  'lounge',
#  'aravon',
#  'gordon',
#  'report',
#  'hair',
#  'birkenstock',
#  'gwyneth',
#  'sporto',
#  'flat',
#  'chinese',
#  'superga',
#  'ecco',
#  'stuart',
#  'soles',
#  'blowfish',
#  'nason',
#  'splendid',
#  'golf',
#  'chrome',
#  'pediped',
#  'orthaheel',
#  'madden',
#  'travis',
#  'brand',
#  'hardy',
#  'arcopedico',
#  'mcq',
#  'tundra',
#  'ektelon',
#  'bandolino',
#  '9',
#  'edmonds',
#  'rsvp',
#  'osiris',
#  'saucony',
#  'satin',
#  'belt',
#  'dan',
#  'keen',
#  'levi',
#  'camper',
#  'moxy',
#  'walk',
#  'ros',
#  'glove',
#  'jeffery',
#  'issue',
#  'floats',
#  'durango',
#  'laredo',
#  'cradles',
#  'fiel',
#  'ugg',
#  'fergie',
#  'badgley',
#  'meucci',
#  'french',
#  'luxury',
#  'rogers',
#  'ten',
#  'type',
#  'onex',
#  'california',
#  'cushe',
#  'callaway',
#  'elephantito',
#  'rockport',
#  'de',
#  'scarpa',
#  'bedstu',
#  'zoe',
#  'top',
#  'crocs',
#  'brooks',
#  'worx',
#  'matiko',
#  'ruiz',
#  'dagger',
#  'jumping',
#  'dolce',
#  'testoni',
#  'gore',
#  'scott',
#  'water',
#  'santana',
#  'rite',
#  'spat',
#  'synthetic',
#  'bowling',
#  'prince',
#  'antonio',
#  'stride',
#  'too',
#  'bcbgeneration',
#  'penguin',
#  'orange',
#  'lama',
#  'rossetti',
#  'casual',
#  'under',
#  'loeffler',
#  'giesswein',
#  'spira',
#  'face',
#  'fur',
#  'l',
#  'born',
#  'aldo',
#  'tac',
#  'penny',
#  'bc',
#  'cobb',
#  'minnetonka',
#  'harley',
#  'rebel',
#  'allen',
#  'tate',
#  'superfit',
#  'b',
#  'naturalista',
#  'seychelles',
#  'truth',
#  'girls',
#  'bradley',
#  'cotton',
#  'mesh',
#  'see',
#  'donna',
#  'fossil',
#  'magli',
#  'livie',
#  'blundstone',
#  'wilson',
#  'zigi',
#  'golite',
#  'sox',
#  'garvalin',
#  'monk',
#  'kid',
#  'call',
#  'cavalli',
#  'pro',
#  'bcbgmaxazria',
#  'jeans',
#  'aetrex',
#  'venettini',
#  'fugu',
#  'salt',
#  'ease',
#  'isola',
#  'harlow',
#  'victoire',
#  'kamalikulture',
#  'vans',
#  'originals',
#  'montrail',
#  'patent',
#  'hi',
#  'fly',
#  'izumi',
#  'jacobs',
#  'agatha',
#  'oakley',
#  'snakeskin',
#  'sider',
#  'nurse',
#  'newton',
#  'box',
#  'slvr',
#  'anne',
#  'felt',
#  'biviel',
#  'old',
#  'women',
#  'privo',
#  'etnies',
#  'rosegold',
#  'jacks',
#  'surplus',
#  'boss',
#  'gola',
#  'u',
#  'nylon',
#  'crib',
#  'colt',
#  'magnanni',
#  'friend',
#  'vous',
#  'corduroy',
#  'avia',
#  'romantic',
#  'rose',
#  'randall',
#  'mooz',
#  'freewaters',
#  'rush',
#  'couture',
#  'lifestride',
#  'cobian',
#  'axion',
#  'mojo',
#  'emerica',
#  'patagonia',
#  'marc',
#  'bloch',
#  'geox',
#  'baker',
#  'lips',
#  'plastic',
#  'earth',
#  'naya',
#  'schouler',
#  'inov',
#  'denim',
#  'wolky',
#  'vaneli',
#  'daniel',
#  'polo',
#  'kalso',
#  'stags',
#  'caterpillar',
#  'hatley',
#  'sanita',
#  'adjustable',
#  'caparros',
#  'deer',
#  'donald',
#  'velour',
#  'foamtreads',
#  'run',
#  'pampili',
#  'kamik',
#  'nautilus',
#  'eastland',
#  'pajar',
#  'worishofer',
#  '41',
#  'asolo',
#  'taryn',
#  'unlisted',
#  'by',
#  'boutique',
#  'chooka',
#  'cole',
#  'nine',
#  'kangaroos',
#  'tweed',
#  'ashworth',
#  'heritage',
#  'beeko',
#  'allrounder',
#  'latex',
#  'doo',
#  'o',
#  'mbt',
#  'steel',
#  'dv',
#  'dknyc',
#  'magnum',
#  'ben',
#  'nunn',
#  'label',
#  'faux',
#  'rangoni',
#  'aigle',
#  'dog',
#  'bridal',
#  'quiksilver',
#  'smartdogs',
#  'vince',
#  'style',
#  'flojos',
#  'calvin',
#  'luichiny',
#  'beautifeel',
#  'rieker',
#  'josef',
#  'pink',
#  'rachel',
#  'sergio',
#  'lakai',
#  'callisto',
#  'shoes',
#  'north',
#  'roxy',
#  'deerskin',
#  'house',
#  'classics',
#  'lugz',
#  'kelsi',
#  'slip',
#  'boots',
#  'and',
#  'sam',
#  'alexander',
#  'annie',
#  'ed',
#  'amiana',
#  'twig',
#  'k',
#  'lloyd',
#  'bungee',
#  'brutini',
#  'gbx',
#  'flot',
#  'it',
#  'shoe',
#  'clergerie',
#  'bass',
#  'helle',
#  'cool',
#  'columbia',
#  'madonna',
#  'missoni',
#  'dvs',
#  'james',
#  'vidorreta',
#  'evening',
#  'fred',
#  'slipper',
#  'bush',
#  '1960',
#  'weitzman',
#  'rj',
#  'altra',
#  'layette',
#  'sheepskin',
#  'flats',
#  'sarto',
#  'cordura',
#  'girl',
#  'mountain',
#  'zero',
#  'fox',
#  'junior',
#  'alegria',
#  'sofft',
#  'belle',
#  'perry',
#  'tony',
#  'salomon',
#  'hunter',
#  'chippewa',
#  'spiga',
#  'steve',
#  'costume',
#  'walking',
#  'tec',
#  'vintage',
#  'licence',
#  'franco',
#  'j',
#  'snap',
#  'jones',
#  'mezlan',
#  'minkoff',
#  'paciotti',
#  'asics',
#  'napa',
#  'carlos',
#  'ocean',
#  'klein',
#  'patricia',
#  'cable',
#  'bikkembergs',
#  'chloe',
#  'pelle',
#  'sander',
#  'nappa',
#  'vines',
#  'fila',
#  'post',
#  'spenco',
#  'cork',
#  'steven',
#  'fashion',
#  'limited',
#  'morrison',
#  'american',
#  'johnson',
#  'via',
#  'clogs',
#  'circus',
#  'skechers',
#  'setter',
#  'lassen',
#  'gravati',
#  'tommy',
#  'papillio',
#  'reaction',
#  'button',
#  'australia',
#  'ripstop',
#  'bernardo',
#  'polyurethane',
#  'la',
#  'monkey',
#  'vivobarefoot',
#  'birki',
#  'canadienne',
#  'pearl',
#  'characters',
#  'buddha',
#  'pepper',
#  'bruno',
#  'seavees',
#  'smith',
#  'sanuk',
#  'trotters',
#  'tretorn',
#  'red',
#  'betsey',
#  'robert',
#  'clarks',
#  'irish',
#  'armour',
#  'evolv',
#  'gabbana',
#  'naturalizer',
#  'true',
#  'jambu',
#  'blondo',
#  'stonz',
#  'enzo',
#  'aster',
#  'promiscuous',
#  'hoka',
#  'high',
#  'ups',
#  'haflinger',
#  'men',
#  'cordani',
#  'up',
#  'silk',
#  'zanotti',
#  'tsukihoshi',
#  'souls',
#  'chaco',
#  'vera',
#  'sandal',
#  'sports',
#  'renee',
#  'paul',
#  'stacy',
#  'volcom',
#  'ipath',
#  'sherman',
#  'kate',
#  'rollerblade',
#  'oxfords',
#  'pazitos',
#  'romika',
#  'nicole',
#  'mules',
#  'neoprene',
#  'gravis',
#  'frye',
#  'michaels',
#  'mizuno',
#  'superfeet',
#  'full',
#  'marvin',
#  'trump',
#  'skates',
#  'knit',
#  'be',
#  'lowa',
#  'puma',
#  'black',
#  'hill',
#  'roy',
#  'sebago',
#  'for',
#  'le',
#  'teva',
#  'hilfiger',
#  'five',
#  'vivanz',
#  'fallen',
#  'utility',
#  'zoot',
#  'mia',
#  'line',
#  'martino',
#  'eric',
#  'jrs',
#  'flyers',
#  'plume',
#  'hemp',
#  'roberto',
#  'stetson',
#  'primigi',
#  'clae',
#  'rossi',
#  'step',
#  'chameau',
#  'marchez',
#  'z',
#  'furstenberg',
#  'sigerson',
#  'original',
#  'santoni',
#  'milo',
#  'speedo',
#  'mankind',
#  'adidas',
#  'diesel',
#  'think',
#  'aquatalia',
#  'drew',
#  'hoy',
#  'sole',
#  'khombu',
#  'versace',
#  'dr',
#  'kors',
#  'people',
#  'tic',
#  'to',
#  'sesto',
#  'westwood',
#  'keds',
#  'emerald',
#  'dmsx',
#  'w',
#  'karan',
#  'naturino',
#  'macbeth',
#  'vasque',
#  'vineyard',
#  'ted',
#  'elizabeth',
#  'footwear',
#  'joan',
#  'charles',
#  'burberry',
#  'boat',
#  'me',
#  'sbicca',
#  'raffia',
#  'knee',
#  'firstwalker',
#  'element',
#  'vigotti',
#  'amalfi',
#  'bouquets',
#  'wang',
#  'emu',
#  'toggle',
#  'carhartt',
#  'dyeables',
#  'merrell',
#  'recreation',
#  'ara',
#  'religion',
#  'express',
#  'stingray',
#  'acorn',
#  '3',
#  'volatile',
#  'loop',
#  'choice',
#  'onetruesaxon']

# %%
word2idx['pad']
# Out:
# 10109

# %%
word2idx['eos']
# Out:
# 26828

# %%
word2idx['bos']
# Out:
# 24471

# %%
word2idx['unk']
# Out:
# 201534

# %%
matrix_len = len(sent_one_list_unique)

weights_matrix = np.zeros((matrix_len, 50)) # <PAD> <EOS> <UNK>
words_found = 0
words_missing_count = 0
words_missing_list = []
word2idx = {word: i for i, word in enumerate(sent_one_list_unique)}

# Writing the weights_matrix
for i, word in enumerate(sent_one_list_unique):
    try: 
        weights_matrix[i] = glove[word]
        words_found += 1
    except KeyError:
        words_missing_count += 1
        words_missing_list.append(word)
        # This case is used for '<pad>' as a 500 element
        weights_matrix[i] = glove['unk']

# %%
words_missing_count
# Out:
# 123

# %%
words_missing_list
# Out:
# ['',
#  'prewalker',
#  'garmont',
#  'coloriffics',
#  'mountrek',
#  'fitflop',
#  'softspots',
#  'pikolinos',
#  'havaianas',
#  'dansko',
#  'propet',
#  'earthies',
#  'cienta',
#  'fivefingers',
#  'footmates',
#  'robeez',
#  'ziera',
#  'ahnu',
#  'lumiani',
#  'olukai',
#  'nubuck',
#  'naot',
#  'fitzwell',
#  'pablosky',
#  'fluevog',
#  'hommerson',
#  'softwalk',
#  'fidji',
#  'klogs',
#  'sadock',
#  'daniblack',
#  'ariat',
#  'zamberlan',
#  'aravon',
#  'sporto',
#  'pediped',
#  'orthaheel',
#  'arcopedico',
#  'ektelon',
#  'bandolino',
#  'cushe',
#  'elephantito',
#  'bedstu',
#  'matiko',
#  'bcbgeneration',
#  'giesswein',
#  'superfit',
#  'naturalista',
#  'livie',
#  'blundstone',
#  'zigi',
#  'golite',
#  'garvalin',
#  'bcbgmaxazria',
#  'aetrex',
#  'venettini',
#  'kamalikulture',
#  'montrail',
#  'biviel',
#  'privo',
#  'rosegold',
#  'magnanni',
#  'mooz',
#  'freewaters',
#  'lifestride',
#  'emerica',
#  'inov',
#  'wolky',
#  'vaneli',
#  'kalso',
#  'sanita',
#  'foamtreads',
#  'pampili',
#  'kamik',
#  'pajar',
#  'worishofer',
#  'chooka',
#  'beeko',
#  'dknyc',
#  'smartdogs',
#  'flojos',
#  'luichiny',
#  'beautifeel',
#  'lugz',
#  'amiana',
#  'brutini',
#  'gbx',
#  'clergerie',
#  'vidorreta',
#  'layette',
#  'sofft',
#  'mezlan',
#  'paciotti',
#  'spenco',
#  'gravati',
#  'papillio',
#  'vivobarefoot',
#  'birki',
#  'seavees',
#  'sanuk',
#  'evolv',
#  'naturalizer',
#  'blondo',
#  'stonz',
#  'tsukihoshi',
#  'ipath',
#  'pazitos',
#  'romika',
#  'superfeet',
#  'lowa',
#  'vivanz',
#  'primigi',
#  'clae',
#  'marchez',
#  'aquatalia',
#  'khombu',
#  'dmsx',
#  'naturino',
#  'sbicca',
#  'firstwalker',
#  'vigotti',
#  'dyeables',
#  'onetruesaxon']

# %%
# Shape of the weights matrix
NUM_WORDS, VOC_SIZE = weights_matrix.shape[0], weights_matrix.shape[1]

# ADD 'bos' and 'eos' to sent_list and 'pad'

emb_sent=[]
for sent in sent_list:
    emb_sent.append([word2idx[i] for i in sent])
    

print(NUM_WORDS, VOC_SIZE)
print(emb_sent[0])
# Out:
# 889 50
# [775, 221, 175, 758, 756, 131]

# %%
weights_matrix
# Out:
# array([[ 0.      ,  0.      ,  0.      , ...,  0.      ,  0.      ,
#          0.      ],
#        [-0.67446 , -0.34052 ,  0.12976 , ...,  0.21709 ,  0.95675 ,
#          0.13755 ],
#        [-0.24837 , -0.463   ,  0.82342 , ...,  0.34312 ,  0.52278 ,
#         -0.046782],
#        ...,
#        [ 0.20649 ,  0.52208 ,  0.39041 , ..., -0.81835 ,  0.065401,
#          0.033825],
#        [-0.13634 ,  0.43304 , -0.10769 , ...,  0.48265 ,  0.5756  ,
#          0.88982 ],
#        [ 0.      ,  0.      ,  0.      , ...,  0.      ,  0.      ,
#          0.      ]])
